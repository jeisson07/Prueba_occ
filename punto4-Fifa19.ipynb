# %%
  import pandas as pd

# %%
#pd.set_option('display.max_columns', None)
df=pd.read_csv('/content/data_FIFA.csv') 
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age Nationality  Overall  Potential  \
# 0           0  158023           L. Messi   31   Argentina       94         94
# 1           1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2           2  190871          Neymar Jr   26      Brazil       92         93
# 3           3  193080             De Gea   27       Spain       91         93
# 4           4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  ...  Composure Marking  \
# 0         FC Barcelona  €110.5M  €565K  ...       96.0    33.0
# 1             Juventus     €77M  €405K  ...       95.0    28.0
# 2  Paris Saint-Germain  €118.5M  €290K  ...       94.0    27.0
# 3    Manchester United     €72M  €260K  ...       68.0    15.0
# 4      Manchester City    €102M  €355K  ...       88.0    68.0
#
#    StandingTackle  SlidingTackle  GKDiving GKHandling GKKicking GKPositioning  \
# ...

# %% [markdown]
# # **DATA CLEANING**

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age Nationality  Overall  Potential  \
# 0           0  158023           L. Messi   31   Argentina       94         94
# 1           1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2           2  190871          Neymar Jr   26      Brazil       92         93
# 3           3  193080             De Gea   27       Spain       91         93
# 4           4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  ...  Composure Marking  \
# 0         FC Barcelona  €110.5M  €565K  ...       96.0    33.0
# 1             Juventus     €77M  €405K  ...       95.0    28.0
# 2  Paris Saint-Germain  €118.5M  €290K  ...       94.0    27.0
# 3    Manchester United     €72M  €260K  ...       68.0    15.0
# 4      Manchester City    €102M  €355K  ...       88.0    68.0
#
#    StandingTackle  SlidingTackle  GKDiving GKHandling GKKicking GKPositioning  \
# ...

# %%
#pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Nationality        object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 86, dtype: object

# %%
#tamaño del df
df.shape
# Out:
# (18207, 86)

# %% [markdown]
# El df se compone de datos tipo:
# -object
# -int 64
# -float 64

# %% [markdown]
# Tiene las caracteristicas del jugador en principio, como ID,el nombre, edad, nacionalidad, puntuacion general, potencial,Club, valor del mercado, Salario, Puntaje especial, habilidad pie derecho, pie izquierdo, Reputacion internacional, habilidad pie menos habil, tasa de trabajo, tipo de cuerpo, cara real (Y/N),posicion, Numero camiseta, Fecha de union,Equipo prestad, Fecha de contrato, altura y peso.

# %% [markdown]
# Posicion del jugador: Otorga un puntaje valor de tipo object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Despues, el dataset se compone de los puntajes de las diferentes skills del jugador.

# %%
#nombres de las columnas
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Overall',
#        'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
# ...

# %%
#informacion de las columnas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 86 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Nationality               18207 non-null  object
#  5   Overall                   18207 non-null  int64
#  6   Potential                 18207 non-null  int64
#  7   Club                      17966 non-null  object
#  8   Value                     18207 non-null  object
#  9   Wage                      18207 non-null  object
#  10  Special                   18207 non-null  int64
#  11  Preferred Foot            18159 non-null  object
#  12  International Reputation  18159 non-null  float64
# ...

# %%
#info estaditicas de los datos
df.describe().T
# Out:
#                             count           mean           std    min  \
# Unnamed: 0                18207.0    9103.000000   5256.052511    0.0
# ID                        18207.0  214298.338606  29965.244204   16.0
# Age                       18207.0      25.122206      4.669943   16.0
# Overall                   18207.0      66.238699      6.908930   46.0
# Potential                 18207.0      71.307299      6.136496   48.0
# Special                   18207.0    1597.809908    272.586016  731.0
# International Reputation  18159.0       1.113222      0.394031    1.0
# Weak Foot                 18159.0       2.947299      0.660456    1.0
# Skill Moves               18159.0       2.361308      0.756164    1.0
# Jersey Number             18147.0      19.546096     15.947765    1.0
# Crossing                  18159.0      49.734181     18.364524    5.0
# Finishing                 18159.0      45.550911     19.525820    2.0
# ...

# %% [markdown]
# Con la info estadistica se observa:
# - En la edad se tien un rango de 16 a 45 años, siendo el promedio 25 años
# - El puntaje generarl se encuentra entre 46 y 94, con un promedio de 66.

# %%
#valores unicos 
df.nunique()
# Out:
# Unnamed: 0        18207
# ID                18207
# Name              17194
# Age                  29
# Nationality         164
#                   ...
# GKHandling           70
# GKKicking            79
# GKPositioning        79
# GKReflexes           76
# Release Clause     1244
# Length: 86, dtype: int64

# %% [markdown]
# Se tiene que el id es unico para cada jugador, sin embargo, en nombres se repite, en este caso se puede realizar una limpieza por valores repetidos.

# %%
df.isnull().any()
# Out:
# Unnamed: 0        False
# ID                False
# Name              False
# Age               False
# Nationality       False
#                   ...
# GKHandling         True
# GKKicking          True
# GKPositioning      True
# GKReflexes         True
# Release Clause     True
# Length: 86, dtype: bool

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Loaned From    16943
# CDM             2085
# LCM             2085
# LS              2085
# LW              2085
#                ...
# Overall            0
# Nationality        0
# Age                0
# Name               0
# Unnamed: 0         0
# Length: 86, dtype: int64

# %% [markdown]
# Las caracteristicas de posicion de jugador, son las que mas tienen valores nulos en el dataframe.

# %% [markdown]
# Se observa si los datos nulos en altura y peso corresponden al mismo jugador, si es afirmativo, se elimina dicha fila.

# %%
missing_height = df[df['Height'].isnull()].index.tolist()
missing_weight = df[df['Weight'].isnull()].index.tolist()
if missing_height == missing_weight:
    print('They are same')
else:
    print('They are different')
# Out:
# They are same

# %%
df.drop(df.index[missing_height],inplace =True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Loaned From     16895
# CDM              2037
# LCM              2037
# LS               2037
# LW               2037
#                 ...
# ShortPassing        0
# Volleys             0
# Dribbling           0
# Height              0
# Unnamed: 0          0
# Length: 86, dtype: int64

# %% [markdown]
# Se disminuyo el numero de filas con datos nulos.

# %%
import matplotlib.pyplot as plt

# %%
df.hist(ylabelsize=(15),bins=10,figsize=(40,30),xlabelsize=(15),color='blue')
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Overall',
#        'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
# ...

# %%
df.sort_values(['Wage'],ascending=False).groupby('Wage').agg({'Name':'count'})
# Out:
#        Name
# Wage
# €0      241
# €100K     3
# €105K    13
# €10K    319
# €110K    15
# ...     ...
# €96K      4
# €97K      2
# €98K      4
# €99K      4
# €9K     328
#
# [144 rows x 1 columns]

# %% [markdown]
# # **EXPLORATORY ANALYSIS**

# %%
#Se transforma las columnas Value and Wage.
def value_to_int(df_value):
    try:
        value = float(df_value[1:-1])
        suffix = df_value[-1:]

        if suffix == 'M':
            value = value * 1000000
        elif suffix == 'K':
            value = value * 1000
    except ValueError:
        value = 0
    return value


df['Value'] = df['Value'].apply(value_to_int)
df['Wage'] = df['Wage'].apply(value_to_int)
df.rename(columns={'Value': 'Value€','Wage': 'Wage€'}, inplace=True)

# %%
df['avg']=df[['Value€','Wage€']].mean(axis=1)

# %% [markdown]
# Se calcula el promedio en a columna avg

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 0               0  158023            L. Messi   31   Argentina       94
# 1               1   20801   Cristiano Ronaldo   33    Portugal       94
# 2               2  190871           Neymar Jr   26      Brazil       92
# 3               3  193080              De Gea   27       Spain       91
# 4               4  192985        K. De Bruyne   27     Belgium       91
# ...           ...     ...                 ...  ...         ...      ...
# 18202       18202  238813        J. Lundstram   19     England       47
# 18203       18203  243165  N. Christoffersson   19      Sweden       47
# 18204       18204  241638           B. Worman   16     England       47
# 18205       18205  246268      D. Walker-Rice   17     England       47
# 18206       18206  246269           G. Nugent   16     England       46
#
#        Potential                 Club       Value€     Wage€  ...  Marking  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age Nationality  Overall  Potential  \
# 0           0  158023           L. Messi   31   Argentina       94         94
# 1           1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2           2  190871          Neymar Jr   26      Brazil       92         93
# 3           3  193080             De Gea   27       Spain       91         93
# 4           4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club       Value€     Wage€  ...  Marking StandingTackle  \
# 0         FC Barcelona  110500000.0  565000.0  ...     33.0           28.0
# 1             Juventus   77000000.0  405000.0  ...     28.0           31.0
# 2  Paris Saint-Germain  118500000.0  290000.0  ...     27.0           24.0
# 3    Manchester United   72000000.0  260000.0  ...     15.0           21.0
# 4      Manchester City  102000000.0  355000.0  ...     68.0           58.0
#
# ...

# %%
print('Highest earner  : '+str(df.loc[df['Wage€'].idxmax()]['Name']))
print('Maximum Potential : '+str(df.loc[df['Potential'].idxmax()]['Name']))
print('Maximum Overall Perforamnce : '+str(df.loc[df['Overall'].idxmax()]['Name']))
# Out:
# Highest earner  : L. Messi
# Maximum Potential : K. Mbappé
# Maximum Overall Perforamnce : L. Messi

# %%
df_wage=df.sort_values('Wage€', ascending = False)[['Name','Wage€']].head(5)
df_wage
# Out:
#                 Name     Wage€
# 0           L. Messi  565000.0
# 7          L. Suárez  455000.0
# 6          L. Modrić  420000.0
# 1  Cristiano Ronaldo  405000.0
# 8       Sergio Ramos  380000.0

# %%
df_potential=df.sort_values('Potential', ascending = False)[['Name','Potential']].head(5)
df_potential
# Out:
#                  Name  Potential
# 25          K. Mbappé         95
# 0            L. Messi         94
# 1   Cristiano Ronaldo         94
# 15          P. Dybala         94
# 9            J. Oblak         93

# %%
df_overall=df.sort_values('Overall', ascending = False)[['Name','Overall',]].head(5)
df_overall
# Out:
#                 Name  Overall
# 0           L. Messi       94
# 1  Cristiano Ronaldo       94
# 2          Neymar Jr       92
# 3             De Gea       91
# 4       K. De Bruyne       91

# %%
print('Total number of clubs : {0}'.format(df['Club'].nunique()))
print(df['Club'].value_counts().sort_values( ascending = False).head(5))
print(df['Club'].value_counts().sort_values( ascending = False).tail(5))
# Out:
# Total number of clubs : 651
# FC Barcelona           33
# Eintracht Frankfurt    33
# Southampton            33
# Manchester City        33
# Manchester United      33
# Name: Club, dtype: int64
# Atlético Paranaense    20
# Cruzeiro               20
# Sligo Rovers           19
# Limerick FC            19
# Derry City             18
# Name: Club, dtype: int64

# %% [markdown]
# Se observa los clubes con mas jugadores y con menos jugadores.

# %%
df.groupby(['Club'])['Wage€'].sum().sort_values( ascending = False).head(5)
# Out:
# Club
# Real Madrid          5017000.0
# FC Barcelona         4837000.0
# Manchester City      3741000.0
# Manchester United    3391000.0
# Juventus             3292000.0
# Name: Wage€, dtype: float64

# %%
df.groupby(['Club'])['Value€'].sum().sort_values( ascending = False).head(5)
# Out:
# Club
# Real Madrid          874425000.0
# FC Barcelona         852600000.0
# Manchester City      786555000.0
# Juventus             704475000.0
# FC Bayern München    679025000.0
# Name: Value€, dtype: float64

# %%
df.groupby(['Club'])['Wage€'].sum().sort_values( ascending = False).tail(5)
# Out:
# Club
# Shamrock Rovers    22000.0
# Dalkurd FF         22000.0
# Limerick FC        19000.0
# Derry City         19000.0
# Sligo Rovers       19000.0
# Name: Wage€, dtype: float64

# %%
df.groupby(['Club'])['Value€'].sum().sort_values( ascending = False).tail(5)
# Out:
# Club
# Sligo Rovers      3295000.0
# Bohemian FC       3195000.0
# Derry City        2795000.0
# Limerick FC       2040000.0
# Bray Wanderers    1930000.0
# Name: Value€, dtype: float64

# %% [markdown]
# Se observa los equipos que tiene salarios mas altos y los 5 con salarios mas bajos, asi mismo su valor en el mercado.

# %% [markdown]
# Se realiza un comparativo entre la distribucion de salarios y la edad.

# %%
import seaborn as sns
# Compare six clubs in relation to age
some_clubs = ('Real Madrid', 'FC Barcelona', 'Manchester United', 'Manchester City', 'Juventus', 'FC Bayern München')
df_club = df.loc[df['Club'].isin(some_clubs) & df['Age']]

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax = sns.violinplot(x="Club", y="Age", data=df_club);
ax.set_title(label='Distribution of age in some clubs', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of age in some clubs')

# %%
some_clubs = ('Real Madrid', 'FC Barcelona', 'Manchester United', 'Manchester City', 'Juventus', 'FC Bayern München')
df_club = df.loc[df['Club'].isin(some_clubs) & df['Age']]

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax = sns.violinplot(x="Club", y="Wage€", data=df_club);
ax.set_title(label='Distribution of wage in some clubs', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of wage in some clubs')

# %%
# Compare six clubs in relation to age
some_clubs = ('Shamrock Rovers', 'Dalkurd FF', 'Limerick FC', 'Derry City', 'Sligo Rovers')
df_club_min = df.loc[df['Club'].isin(some_clubs) & df['Age']]

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax = sns.violinplot(x="Club", y="Age", data=df_club_min);
ax.set_title(label='Distribution of age in some clubs', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of age in some clubs')

# %% [markdown]
# De las graficas se observa que Juventus tiene el jugador mas longevo en su plantilla.

# %% [markdown]
# El club con mayor media es Juventus y el Real madrid con la menor.

# %%
sns.boxplot(x="Club", y="Age", data=df_club)

# %%
sns.boxplot(x="Club", y="Wage€", data=df_club)

# %%
sns.barplot(x="Club", y="Wage€", data=df_club)

# %% [markdown]
# El equipo con que tiene el salario mas grande en la plantilla es Barcelona, esto concuerda con lo analizado donde era Messi, seguido de Juventus, donde se ecnuentra CR7 y el equipo con menor pico de Salario es Bayern Munich.

# %%
sns.boxplot(x="Club", y="Age", data=df_club_min)

# %% [markdown]
# Se observa que los clubes con menos masa salarial se caracterizan por poseer en su plantilla jugadores Jovenes, donde su promedio no supera 24 años.

# %%
df.columns

# %%
df['Wage€'].hist()

# %%
import numpy as np
p = 20000
df['Wage€'].apply(lambda x: np.tanh(x/p)).hist()

# %% [markdown]
# Se observa que los clubes mas valiosos en el mercado a partir de esto se realiza la distribucion entre salarios y edad.

# %%
sns.jointplot(x=df['Age'],y=df['Potential'],
              joint_kws={'alpha':0.1,'s':5,'color':'red'},
              marginal_kws={'color':'red'})

# %%
sns.jointplot(x=df['Age'],y=df['Wage€'],
              joint_kws={'alpha':0.1,'s':5,'color':'red'},
              marginal_kws={'color':'red'})

# %% [markdown]
# Se observa que los jugadores longevos y mas jovenes tienen los salarios mas bajos.

# %%
df.plot.scatter('Age','Wage€')
plt.show()

# %%
df.plot.scatter('International Reputation','Value€')
plt.show()
